# %%
import numpy as np
from pandas import read_csv
from pandas import DataFrame
from pandas import Grouper
from matplotlib import pyplot
series = read_csv('GSD.csv')
df = pd.read_csv('GSD.csv')

# %%
df.head()
# Out:
#    Year      GSD
# 0  1990  10000.0
# 1  1991   9000.0
# 2  1992   8000.0
# 3  1993   7000.0
# 4  1994   6000.0

# %%
a, b = np.polyfit(Year, GSD, deg=1)
y_est = a * Year + b
y_err = Year.std() * np.sqrt(1/len(Year) + (Year - Year.mean())**2 / np.sum((Year - Year.mean())**2))
fig, ax = plt.subplots()
ax.plot(Year, y_est, '-')
ax.fill_between(Year, y_est - y_err, y_est + y_err, alpha=0.2)
ax.plot(Year, GSD, 'o', color='tab:brown')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 a, b = np.polyfit(Year, GSD, deg=1)
#       2 y_est = a * Year + b
#       3 y_err = Year.std() * np.sqrt(1/len(Year) + (Year - Year.mean())**2 / np.sum((Year - Year.mean())**2))
#
# NameError: name 'Year' is not defined
